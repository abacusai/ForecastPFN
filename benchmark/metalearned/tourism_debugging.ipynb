# %%
from main_ForecastPFN import *
# Out:
# 2023-04-25 21:37:47.370003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-25 21:37:47.410646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-25 21:37:47.410946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
path = 'project/shared/repeats=0,lookback_period=2,loss_name=MAPE,source_dataset=M4'

# %%
experiment_parameters = load_experiment_parameters(path)
source_dataset_name = experiment_parameters['source_dataset'] if 'source_dataset' in experiment_parameters else 'M4'
loss_name = experiment_parameters['loss_name']

model_horizons = {
    'Y4': 4,
    'Y6': 6,
    'Q8': 8,
    'M18': 18,
    'M24': 24,
    'W13': 13,
    'D14': 14,
    'H24': 24,
    'H48': 48,
}

if source_dataset_name == 'M4':
    source_dataset, _ = M3Dataset(M3Meta.dataset_path).standard_split()
    model_sps = {
        'Y4': 'Yearly',
        'Y6': 'Yearly',
        'Q8': 'Quarterly',
        'M18': 'Monthly',
        'M24': 'Monthly',
        'W13': 'Weekly',
        'D14': 'Daily',
        'H24': 'Hourly',
        'H48': 'Hourly',
    }
elif source_dataset_name == 'FRED':
    source_dataset, _ = FredDataset(FredMeta.dataset_path).standard_split()
    model_sps = {
        'Y4': 'Yearly',
        'Y6': 'Yearly',
        'Q8': 'Quarterly',
        'M18': 'Monthly',
        'M24': 'Monthly',
        'W13': 'Monthly',
        'D14': 'Monthly',
        'H24': 'Monthly',
        'H48': 'Monthly',
    }
elif source_dataset_name == 'M3':
    source_dataset, _ = M3Dataset(M3Meta.dataset_path).standard_split()
    model_sps = {
        'Y4': 'M3Year',
        'Y6': 'M3Year',
        'Q8': 'M3Quart',
        'M18': 'M3Month',
        'M24': 'M3Month',
        'W13': 'M3Month',
        'D14': 'M3Other',
        'H24': 'M3Other',
        'H48': 'M3Other',
    }
else:
    raise Exception(f'Unknown source dataset {source_dataset_name}')

tl_models = {}
for model_name, horizon in model_horizons.items():
    input_size = experiment_parameters['lookback_period'] * horizon
    model = Exp_ForecastPFN(None)

    tl_models[model_name] = {'p_model': model, 'p_input_size': input_size, 'p_horizon': horizon}
print(tl_models['M24'])
# Out:
# {'p_model': <exp.exp_ForecastPFN.Exp_ForecastPFN object at 0x7f1120707370>, 'p_input_size': 48, 'p_horizon': 24}

# %%
target_input, target_output = TourismDataset(
        TourismMeta.dataset_path).standard_split()
in_bundle, out_bundle, sp = target_input, target_output, 'Yearly'
p_model, p_input_size, p_horizon = tl_models['M24']['p_model'], tl_models['M24']['p_input_size'], tl_models['M24']['p_horizon']
# p_input_size, p_horizon = 7*18, 18

# %%
pred = pd.read_csv(f'{path}/tourism.csv')

# %%
true = pd.DataFrame(target_output.values())
true.insert(0, 'id', pred['id'])
true.columns = pred.columns

# %%
pred['mse'] = ((true - pred[pred.columns[1:]])**2).mean(axis=1)
pred['mape'] = (100 * (true - pred[pred.columns[1:]]).abs() / true).mean(axis=1)

# %%
ts_input = target_input.time_stamps()
ts_output = target_output.time_stamps()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

desc_sort_mse = pred.sort_values('mape', ascending=False).index
idxs = range(10)
preds = pred.iloc[desc_sort_mse[idxs]]
trues = true.iloc[desc_sort_mse[idxs]]

for (i,p_pfn), (i,y) in zip(preds.iterrows(), trues.iterrows()):
    
    row_idx = i
    row_name = p_pfn['id'] + '\nmape: ' + str(p_pfn['mape'])
    times = np.append(ts_input[i], ts_output[row_idx])
    x = target_input.values()[i]
    p_pfn = p_pfn[preds.columns[1:-1]]
    y = y[trues.columns[1:]]
    
    
    plt.plot(times, np.append(x,y.dropna()), label="true")
    p_pfn = p_pfn[[x for x in p_pfn.index if 'V' in x]]
    plt.plot(times, np.append(x,p_pfn.dropna()), label="ForecastPFN")

    plt.plot(ts_input[i], x, label="history")
    plt.legend()
    plt.title(row_name)
    plt.xticks(rotation=45)
    plt.show()

# %%
plt.scatter([x[0] for x in ts_output],pred['mape'])
plt.yscale('log')

# %%
plt.scatter([x.max()/x.min() for x in target_input.values()],pred['mape'])
plt.xscale('log')
plt.yscale('log')
